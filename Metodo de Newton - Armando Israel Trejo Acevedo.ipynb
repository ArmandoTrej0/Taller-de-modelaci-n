# %% [markdown]
# # Métodos Numéricos Para Encontrar Las Raices De Una Función
#
# ## Método de Newton-Raphson
# Recordarán de la clase anterior que una forma de encontrar el 0 de una función es por medio del método de Newton-Raphson. Como vieron en la clase, este método está dado por la siguiente relación de recurrencia:
# $$
# x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}
# $$

# %% [markdown]
# ### Ejercicio:
# Calcularemos las dos raíces del polinomio $p(x)=2x^4 +24x^3 +61x^2 −16x+1$ cerca de $x=0.1$ usando el método de Newton-Raphson y calcularemos la eficiencia de los dos. Método de Mewton-Raphson
#
# **Paso 1:** Programa una función que aplique el método de Newton-Raphson a una función en general. Tu función debe tener dos criterios de paro.
# - El primero será la tolerancia del algoritmo, en la cual especificamos que tan pequeño queremos hacer el valor de f. Es decir, si la tolerancia es ε se deberá de cumplir que $|f (x_n)|<ε$ para que pare.
# - El otro criterio de paro deberá ser un número máximo de iteraciones $N$ en caso de que nunca se alcance la tolerancia. Además debe recibir la condición inicial, $x_0$, la función $f$ y la función $f′$. Finalmente, debe regresar una lista con todos los valores de las iteraciones.

# %%
def NewtonRaphson(x0, f, df, tol = 1*10**(-10), nMax = 10000):
  X=[x0]
  i=0
  while i<nMax and f(X[i])<tol:
    x=X[i]-(f(X[i])/df(X[i]))
    X.append(x)
    i=i+1
  return X

# %%
def p(x):
  u=(2*(x**4))+(24*(x**3))+(61*(x**2))-(16*x)+1
  return u

# %%
def dp(x):
  u=(8*(x**3))+(72*(x**2))+(122*(x))-16
  return u

# %%
p( 0.11113281250000001)
# Out:
# 0.008501797254665822

# %%
NewtonRaphson(0.1, p, dp,tol = 1*10**(-10), nMax = 10000)
# Out:
# [0.1]

# %% [markdown]
# **Paso 2:**
#
# Como se vio en le sección anterior, el resultado del método depende de la condición inicial.
# Por ello vale la pena echar un vistazo a la gráfica para saber con que condiciones iniciar el
# método.
# En este ejercicio deberán graficar $P(x)$ para ver aproximadamente en que valores se
# encuentran las raices cercanas a $x=0.1$. Una vez que hayan determinado dichos valores
# prueben su función con las diferentes condiciones iniciales y evaluen $P(x)$ en los valores
# obtenidos para corroborar que sí son ceros.
# Prueba tu función con una tolerancia de $10^{−10}$ y un número máximo de iteraciones de
# $10,000$.
# Pista : Deben obtener dos valores distintos en el intervalo $[0.120,0.125]$.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Comienza aquí tu código

import numpy as np
import matplotlib.pyplot as plt
# Comienza aquí tu código
def p(x):
    return
plt.plot(np.linspace(0.12,0.125),p(np.linspace(0.12,0.125)), color ='maroon')
plt.title('$2x^{4} + 24x^{3} + 61x^{2} -16x +1$')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-8e864b7dcc87> in <cell line: 10>()
#       8 def p(x):
#       9     return
# ---> 10 plt.plot(np.linspace(0.12,0.125),p(np.linspace(0.12,0.125)), color ='maroon')
#      11 plt.title('$2x^{4} + 24x^{3} + 61x^{2} -16x +1$')
#      12 plt.grid(True)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
# ...

# %%
def P(x):
    return
def dP(x):
    return
#Raiz del lado derecho
x1 = NewtonRaphson(0.15, P, dP)
#Raiz del lado izquierdo
x2 = NewtonRaphson(0.05, P, dP)
print("Las raíces encontradas son: x1 = {} y x2 = {}".format(x1[-1],x2[-1]))
print("Los valores del polinomio en las raíces son: P(x1) = {} y P(x2)= {}".format(P(x1[-1]),P(x2[-1])))
plt.plot(np.linspace(-10,5, 1000),p(np.linspace(-10,5, 1000)), color ='maroon')
plt.title('$2x^{4} + 24x^{3} + 61x^{2} -16x +1$')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-25ffc2efd2e4> in <cell line: 6>()
#       4     return
#       5 #Raiz del lado derecho
# ----> 6 x1 = NewtonRaphson(0.15, P, dP)
#       7 #Raiz del lado izquierdo
#       8 x2 = NewtonRaphson(0.05, P, dP)
#
# <ipython-input-1-d590af649d1c> in NewtonRaphson(x0, f, df, tol, nMax)
#       2   X=[x0]
#       3   i=0
# ----> 4   while i<nMax and f(X[i])<tol:
#       5     x=X[i]-(f(X[i])/df(X[i]))
#       6     X.append(x)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'float'

# %%
#Raiz del lado izquierdo
x3 = NewtonRaphson(-10, P, dP)
#Raiz del lado derecho
x4 = NewtonRaphson(-3, P, dP)
print("Las raíces encontradas son: x3 = {} y x4 = {}".format(x3[-1],x4[-1]))
print("Los valores del polinomio en las raíces son: P(x3) = {} y P(x4)= {}".format(P(x3[-1]),P(x4[-1])))

# %% [markdown]
# ### Apéndice
# **Para jugar con el método de Newton-Raphson**
#
# En el siguiente link pueden probar el método con distintas funciones y diferentes números de iteraciones y ver como se comporta gráficamente. https://www.geogebra.org/m/XCrwWHzy
